# %% [markdown]
# # Library

# %%
#===========================================================
# Library
#===========================================================
import os
import gc
from logging import getLogger, INFO, StreamHandler, FileHandler, Formatter
from contextlib import contextmanager
import time

import numpy as np
import pandas as pd
import scipy as sp
import random

import matplotlib.pyplot as plt
import seaborn as sns

from functools import partial

from sklearn.model_selection import StratifiedKFold, GroupKFold, KFold
from sklearn import preprocessing
import category_encoders as ce
from sklearn.metrics import mean_squared_error

import torch

import lightgbm as lgb

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Utils

# %%
#===========================================================
# Utils
#===========================================================
def get_logger(filename='log'):
    logger = getLogger(__name__)
    logger.setLevel(INFO)
    handler1 = StreamHandler()
    handler1.setFormatter(Formatter("%(message)s"))
    handler2 = FileHandler(filename=f"{filename}.log")
    handler2.setFormatter(Formatter("%(message)s"))
    logger.addHandler(handler1)
    logger.addHandler(handler2)
    return logger

logger = get_logger()


@contextmanager
def timer(name):
    t0 = time.time()
    yield
    logger.info(f'[{name}] done in {time.time() - t0:.0f} s')


def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

    
def load_df(path, df_name, debug=False):
    if path.split('.')[-1]=='csv':
        df = pd.read_csv(path)
        if debug:
            df = pd.read_csv(path, nrows=1000)
    elif path.split('.')[-1]=='pkl':
        df = pd.read_pickle(path)
    if logger==None:
        print(f"{df_name} shape / {df.shape} ")
    else:
        logger.info(f"{df_name} shape / {df.shape} ")
    return df

# %% [markdown]
# # Config

# %%
#===========================================================
# Config
#===========================================================
OUTPUT_DICT = ''

ID = 'Id'
TARGET_COLS = ['age', 'domain1_var1', 'domain1_var2', 'domain2_var1', 'domain2_var2']
SEED = 42
seed_everything(seed=SEED)

N_FOLD = 5

# %% [markdown]
# # Data Loading

# %%
train = pd.read_csv('../input/trends-assessment-prediction/train_scores.csv', dtype={'Id':str})\
            .dropna().reset_index(drop=True) # to make things easy
reveal_ID = pd.read_csv('../input/trends-assessment-prediction/reveal_ID_site2.csv', dtype={'Id':str})
ICN_numbers = pd.read_csv('../input/trends-assessment-prediction/ICN_numbers.csv')
loading = pd.read_csv('../input/trends-assessment-prediction/loading.csv', dtype={'Id':str})
fnc = pd.read_csv('../input/trends-assessment-prediction/fnc.csv', dtype={'Id':str})
sample_submission = pd.read_csv('../input/trends-assessment-prediction/sample_submission.csv', dtype={'Id':str})

# %%
train.head()
# Out:
#       Id        age  domain1_var1  domain1_var2  domain2_var1  domain2_var2
# 0  10001  57.436077     30.571975     62.553736     53.325130     51.427998
# 1  10002  59.580851     50.969456     67.470628     60.651856     58.311361
# 2  10004  71.413018     53.152498     58.012103     52.418389     62.536641
# 3  10007  38.617381     49.197021     65.674285     40.151376     34.096421
# 4  10008  35.326582     15.769168     65.782269     44.643805     50.448485

# %%
reveal_ID.head()
# Out:
#       Id
# 0  10012
# 1  10014
# 2  10020
# 3  10034
# 4  10059

# %%
ICN_numbers.head()
# Out:
#    ICN_number
# 0          69
# 1          53
# 2          98
# 3          99
# 4          45

# %%
loading.head()
# Out:
#       Id     IC_01     IC_07     IC_05     IC_16     IC_26     IC_06  \
# 0  10001  0.006070  0.014466  0.004136  0.000658 -0.002742  0.005033
# 1  10002  0.009087  0.009291  0.007049 -0.002076 -0.002227  0.004605
# 2  10003  0.008151  0.014684  0.010444 -0.005293 -0.002913  0.015042
# 3  10004  0.004675  0.000957  0.006154 -0.000429 -0.001222  0.011755
# 4  10005 -0.000398  0.006878  0.009051  0.000369  0.000336  0.010679
#
#       IC_10     IC_09     IC_18  ...     IC_08     IC_03     IC_21     IC_28  \
# 0  0.016720  0.003484  0.001797  ...  0.018246  0.023711  0.009177 -0.013929
# 1  0.012277  0.002946  0.004086  ...  0.014635  0.022556  0.012004 -0.011814
# 2  0.017745  0.003930 -0.008021  ...  0.019565  0.030616  0.018184 -0.010469
# 3  0.013010  0.000193  0.008075  ...  0.002658  0.022266  0.005956 -0.010595
# 4  0.010352  0.003637  0.004180  ...  0.009702  0.017257  0.005454 -0.008591
#
#       IC_11     IC_20     IC_30     IC_22     IC_29     IC_14
# 0  0.030696  0.010496  0.002892 -0.023235  0.022177  0.017192
# 1  0.022479  0.005739  0.002880 -0.016609  0.025543  0.014524
# 2  0.029799  0.015435  0.005211 -0.028882  0.031427  0.018164
# 3  0.024078 -0.000319  0.005866 -0.015182  0.024476  0.014760
# 4  0.019416  0.000786  0.002692 -0.019814  0.017105  0.013316
#
# [5 rows x 27 columns]

# %%
fnc.head()
# Out:
#       Id  SCN(53)_vs_SCN(69)  SCN(98)_vs_SCN(69)  SCN(99)_vs_SCN(69)  \
# 0  10001            0.368580            0.166876            0.438148
# 1  10002            0.151696           -0.024819            0.217504
# 2  10003            0.343415            0.109974            0.741641
# 3  10004            0.132793            0.258255            0.490769
# 4  10005            0.291921            0.251254            0.416470
#
#    SCN(45)_vs_SCN(69)  ADN(21)_vs_SCN(69)  ADN(56)_vs_SCN(69)  \
# 0            0.341007           -0.186251            0.049096
# 1            0.418072           -0.227234           -0.064052
# 2            0.578558           -0.676446           -0.436960
# 3            0.342717            0.091112            0.107969
# 4            0.511719           -0.362626           -0.164710
#
#    SMN(3)_vs_SCN(69)  SMN(9)_vs_SCN(69)  SMN(2)_vs_SCN(69)  ...  \
# 0           0.121417          -0.174268          -0.231578  ...
# 1          -0.143832          -0.118116          -0.054825  ...
# 2          -0.295663          -0.377790          -0.344963  ...
# 3           0.029220          -0.026237           0.094742  ...
# 4          -0.289059          -0.015537          -0.087316  ...
#
#    CBN(13)_vs_DMN(94)  CBN(18)_vs_DMN(94)  CBN(4)_vs_DMN(94)  \
# 0           -0.149279            0.552841           0.131046
# 1           -0.214216           -0.039792           0.143014
# 2           -0.154941            0.136850          -0.022361
# 3           -0.130339            0.309540           0.141469
# 4           -0.139525            0.394932           0.040443
#
#    CBN(7)_vs_DMN(94)  CBN(18)_vs_CBN(13)  CBN(4)_vs_CBN(13)  \
# 0           0.335446            0.394867          -0.042853
# 1          -0.189962            0.498373           0.444231
# 2           0.137625            0.677972           0.409412
# 3           0.030853            0.344394           0.214097
# 4           0.428334            0.498837           0.266755
#
#    CBN(7)_vs_CBN(13)  CBN(4)_vs_CBN(18)  CBN(7)_vs_CBN(18)  CBN(7)_vs_CBN(4)
# 0           0.124627          -0.060712           0.515964          0.290488
# 1           0.592438           0.028649           0.705524          0.248327
# 2           0.563892           0.438684           0.618204          0.284474
# 3           0.317556           0.012435           0.665937          0.081358
# 4           0.227379           0.028984           0.752343          0.087898
#
# [5 rows x 1379 columns]

# %%
sample_submission.head()
# Out:
#                    Id  Predicted
# 0           10003_age       50.0
# 1  10003_domain1_var1       50.0
# 2  10003_domain1_var2       50.0
# 3  10003_domain2_var1       50.0
# 4  10003_domain2_var2       50.0

# %%
sample_submission['ID_num'] = sample_submission[ID].apply(lambda x: int(x.split('_')[0]))
test = pd.DataFrame({ID: sample_submission['ID_num'].unique().astype(str)})
del sample_submission['ID_num']; gc.collect()
test.head()
# Out:
#       Id
# 0  10003
# 1  10006
# 2  10010
# 3  10011
# 4  10012

# %% [markdown]
# # FE

# %%
# merge
train = train.merge(loading, on=ID, how='left')
train = train.merge(fnc, on=ID, how='left')
train.head()
# Out:
#       Id        age  domain1_var1  domain1_var2  domain2_var1  domain2_var2  \
# 0  10001  57.436077     30.571975     62.553736     53.325130     51.427998
# 1  10002  59.580851     50.969456     67.470628     60.651856     58.311361
# 2  10004  71.413018     53.152498     58.012103     52.418389     62.536641
# 3  10007  38.617381     49.197021     65.674285     40.151376     34.096421
# 4  10008  35.326582     15.769168     65.782269     44.643805     50.448485
#
#       IC_01     IC_07     IC_05     IC_16  ...  CBN(13)_vs_DMN(94)  \
# 0  0.006070  0.014466  0.004136  0.000658  ...           -0.149279
# 1  0.009087  0.009291  0.007049 -0.002076  ...           -0.214216
# 2  0.004675  0.000957  0.006154 -0.000429  ...           -0.130339
# 3  0.005192  0.010585  0.012160 -0.000920  ...           -0.150218
# 4  0.007745  0.009748  0.009356 -0.004219  ...           -0.080562
#
#    CBN(18)_vs_DMN(94)  CBN(4)_vs_DMN(94)  CBN(7)_vs_DMN(94)  \
# 0            0.552841           0.131046           0.335446
# 1           -0.039792           0.143014          -0.189962
# 2            0.309540           0.141469           0.030853
# 3            0.408926           0.072004           0.157582
# 4            0.005339          -0.386757           0.020546
#
#    CBN(18)_vs_CBN(13)  CBN(4)_vs_CBN(13)  CBN(7)_vs_CBN(13)  \
# 0            0.394867          -0.042853           0.124627
# 1            0.498373           0.444231           0.592438
# 2            0.344394           0.214097           0.317556
# 3            0.532046           0.355448           0.462675
# 4            0.518383           0.408071           0.465851
#
#    CBN(4)_vs_CBN(18)  CBN(7)_vs_CBN(18)  CBN(7)_vs_CBN(4)
# 0          -0.060712           0.515964          0.290488
# 1           0.028649           0.705524          0.248327
# 2           0.012435           0.665937          0.081358
# 3           0.161005           0.703679          0.293607
# 4           0.112785           0.574596          0.178531
#
# [5 rows x 1410 columns]

# %%
# merge
test = test.merge(loading, on=ID, how='left')
test = test.merge(fnc, on=ID, how='left')
test.head()
# Out:
#       Id     IC_01     IC_07     IC_05     IC_16     IC_26     IC_06  \
# 0  10003  0.008151  0.014684  0.010444 -0.005293 -0.002913  0.015042
# 1  10006  0.000334  0.005311  0.010053  0.006920 -0.000065  0.015310
# 2  10010  0.007103  0.006144  0.009770 -0.002884 -0.001346  0.015651
# 3  10011  0.004362  0.010240  0.010167  0.004492 -0.001623  0.017381
# 4  10012 -0.007521 -0.003918  0.008434 -0.001145  0.002017  0.015065
#
#       IC_10     IC_09     IC_18  ...  CBN(13)_vs_DMN(94)  CBN(18)_vs_DMN(94)  \
# 0  0.017745  0.003930 -0.008021  ...           -0.154941            0.136850
# 1  0.016543  0.004794  0.003982  ...           -0.053606            0.240957
# 2  0.011613 -0.003291  0.013423  ...           -0.244332            0.272077
# 3  0.014680  0.007453  0.008786  ...           -0.099726            0.557121
# 4  0.019616  0.004140 -0.003744  ...           -0.025230            0.203298
#
#    CBN(4)_vs_DMN(94)  CBN(7)_vs_DMN(94)  CBN(18)_vs_CBN(13)  \
# 0          -0.022361           0.137625            0.677972
# 1           0.270419           0.367692            0.354501
# 2           0.193523           0.192254            0.563982
# 3           0.042626           0.179456            0.416546
# 4           0.173427           0.046047            0.561599
#
#    CBN(4)_vs_CBN(13)  CBN(7)_vs_CBN(13)  CBN(4)_vs_CBN(18)  CBN(7)_vs_CBN(18)  \
# 0           0.409412           0.563892           0.438684           0.618204
# 1           0.486364           0.416908           0.285274           0.693490
# 2           0.124482           0.488926           0.083368           0.774299
# 3           0.445402           0.436909           0.165182           0.591561
# 4           0.418268           0.609517           0.218285           0.790285
#
#    CBN(7)_vs_CBN(4)
# 0          0.284474
# 1          0.448526
# 2          0.129327
# 3          0.306678
# 4          0.301010
#
# [5 rows x 1405 columns]

# %% [markdown]
# # Prepare folds

# %%
folds = train[[ID]+TARGET_COLS].copy()
Fold = KFold(n_splits=N_FOLD, shuffle=True, random_state=SEED)
for n, (train_index, val_index) in enumerate(Fold.split(folds, folds[TARGET_COLS])):
    folds.loc[val_index, 'fold'] = int(n)
folds['fold'] = folds['fold'].astype(int)
folds.head()
# Out:
#       Id        age  domain1_var1  domain1_var2  domain2_var1  domain2_var2  \
# 0  10001  57.436077     30.571975     62.553736     53.325130     51.427998
# 1  10002  59.580851     50.969456     67.470628     60.651856     58.311361
# 2  10004  71.413018     53.152498     58.012103     52.418389     62.536641
# 3  10007  38.617381     49.197021     65.674285     40.151376     34.096421
# 4  10008  35.326582     15.769168     65.782269     44.643805     50.448485
#
#    fold
# 0     2
# 1     3
# 2     3
# 3     4
# 4     4

# %% [markdown]
# # MODEL

# %%
#===========================================================
# model
#===========================================================
def run_single_lightgbm(param, train_df, test_df, folds, features, target, fold_num=0, categorical=[]):
    
    trn_idx = folds[folds.fold != fold_num].index
    val_idx = folds[folds.fold == fold_num].index
    logger.info(f'len(trn_idx) : {len(trn_idx)}')
    logger.info(f'len(val_idx) : {len(val_idx)}')
    
    if categorical == []:
        trn_data = lgb.Dataset(train_df.iloc[trn_idx][features],
                               label=target.iloc[trn_idx])
        val_data = lgb.Dataset(train_df.iloc[val_idx][features],
                               label=target.iloc[val_idx])
    else:
        trn_data = lgb.Dataset(train_df.iloc[trn_idx][features],
                               label=target.iloc[trn_idx],
                               categorical_feature=categorical)
        val_data = lgb.Dataset(train_df.iloc[val_idx][features],
                               label=target.iloc[val_idx],
                               categorical_feature=categorical)

    oof = np.zeros(len(train_df))
    predictions = np.zeros(len(test_df))

    num_round = 10000

    clf = lgb.train(param,
                    trn_data,
                    num_round,
                    valid_sets=[trn_data, val_data],
                    verbose_eval=100,
                    early_stopping_rounds=100)

    oof[val_idx] = clf.predict(train_df.iloc[val_idx][features], num_iteration=clf.best_iteration)

    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = features
    fold_importance_df["importance"] = clf.feature_importance(importance_type='gain')
    fold_importance_df["fold"] = fold_num

    predictions += clf.predict(test_df[features], num_iteration=clf.best_iteration)
    
    # RMSE
    logger.info("fold{} RMSE score: {:<8.5f}".format(fold_num, np.sqrt(mean_squared_error(target[val_idx], oof[val_idx]))))
    
    return oof, predictions, fold_importance_df


def run_kfold_lightgbm(param, train, test, folds, features, target, n_fold=5, categorical=[]):
    
    logger.info(f"================================= {n_fold}fold lightgbm =================================")
    
    oof = np.zeros(len(train))
    predictions = np.zeros(len(test))
    feature_importance_df = pd.DataFrame()

    for fold_ in range(n_fold):
        print("Fold {}".format(fold_))
        _oof, _predictions, fold_importance_df = run_single_lightgbm(param,
                                                                     train,
                                                                     test,
                                                                     folds,
                                                                     features,
                                                                     target,
                                                                     fold_num=fold_,
                                                                     categorical=categorical)
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
        oof += _oof
        predictions += _predictions / n_fold

    # RMSE
    logger.info("CV RMSE score: {:<8.5f}".format(np.sqrt(mean_squared_error(target, oof))))

    logger.info(f"=========================================================================================")
    
    return feature_importance_df, predictions, oof

    
def show_feature_importance(feature_importance_df, name):
    cols = (feature_importance_df[["Feature", "importance"]]
            .groupby("Feature")
            .mean()
            .sort_values(by="importance", ascending=False)[:50].index)
    best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

    plt.figure(figsize=(8, 16))
    sns.barplot(x="importance", y="Feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('Features importance (averaged/folds)')
    plt.tight_layout()
    plt.savefig(OUTPUT_DICT+f'feature_importance_{name}.png')

# %%
prediction_dict = {}
oof_dict = {}

for TARGET in TARGET_COLS:
    
    logger.info(f'### LGB for {TARGET} ###')

    target = train[TARGET]
    test[TARGET] = np.nan

    # features
    cat_features = []
    num_features = [c for c in test.columns if (test.dtypes[c] != 'object') & (c not in cat_features)]
    features = num_features + cat_features
    drop_features = [ID] + TARGET_COLS
    features = [c for c in features if c not in drop_features]

    if cat_features:
        ce_oe = ce.OrdinalEncoder(cols=cat_features, handle_unknown='impute')
        ce_oe.fit(train)
        train = ce_oe.transform(train)
        test = ce_oe.transform(test)
        
    lgb_param = {'objective': 'regression',
             'metric': 'rmse',
             'boosting_type': 'gbdt',
             'learning_rate': 0.03,
             'seed': SEED,
             'max_depth': -1,
             'verbosity': -1,
            }

    feature_importance_df, predictions, oof = run_kfold_lightgbm(lgb_param, train, test, folds, features, target, 
                                                                 n_fold=N_FOLD, categorical=cat_features)
    
    prediction_dict[TARGET] = predictions
    oof_dict[TARGET] = oof
    
    show_feature_importance(feature_importance_df, TARGET)
# Out:
# ### LGB for age ###
# ================================= 5fold lightgbm =================================
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 0
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 7.37496	valid_1's rmse: 9.73299
# [200]	training's rmse: 5.09748	valid_1's rmse: 9.46754
# [300]	training's rmse: 3.6429	valid_1's rmse: 9.39453
# [400]	training's rmse: 2.67232	valid_1's rmse: 9.3699
# [500]	training's rmse: 1.99342	valid_1's rmse: 9.35614
# [600]	training's rmse: 1.50044	valid_1's rmse: 9.34867
# [700]	training's rmse: 1.135	valid_1's rmse: 9.34263
# [800]	training's rmse: 0.864362	valid_1's rmse: 9.34139
# [900]	training's rmse: 0.659166	valid_1's rmse: 9.3407
# [1000]	training's rmse: 0.504144	valid_1's rmse: 9.33952
# [1100]	training's rmse: 0.3847	valid_1's rmse: 9.33994
# Early stopping, best iteration is:
# [1025]	training's rmse: 0.470899	valid_1's rmse: 9.33886
# fold0 RMSE score: 9.33886
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 7.35462	valid_1's rmse: 9.85943
# [200]	training's rmse: 5.08667	valid_1's rmse: 9.60182
# [300]	training's rmse: 3.65147	valid_1's rmse: 9.5475
# [400]	training's rmse: 2.67797	valid_1's rmse: 9.52408
# [500]	training's rmse: 1.99315	valid_1's rmse: 9.51811
# [600]	training's rmse: 1.50532	valid_1's rmse: 9.50929
# [700]	training's rmse: 1.14297	valid_1's rmse: 9.50554
# [800]	training's rmse: 0.872099	valid_1's rmse: 9.50119
# [900]	training's rmse: 0.66861	valid_1's rmse: 9.4953
# [1000]	training's rmse: 0.512199	valid_1's rmse: 9.49291
# Early stopping, best iteration is:
# [962]	training's rmse: 0.566124	valid_1's rmse: 9.49202
# fold1 RMSE score: 9.49202
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 7.21867	valid_1's rmse: 10.7407
# [200]	training's rmse: 4.99168	valid_1's rmse: 10.4354
# [300]	training's rmse: 3.57696	valid_1's rmse: 10.3717
# [400]	training's rmse: 2.62214	valid_1's rmse: 10.3361
# [500]	training's rmse: 1.95549	valid_1's rmse: 10.3197
# [600]	training's rmse: 1.46872	valid_1's rmse: 10.3156
# [700]	training's rmse: 1.11104	valid_1's rmse: 10.3057
# [800]	training's rmse: 0.846201	valid_1's rmse: 10.3014
# [900]	training's rmse: 0.641621	valid_1's rmse: 10.2976
# [1000]	training's rmse: 0.490733	valid_1's rmse: 10.2923
# [1100]	training's rmse: 0.374667	valid_1's rmse: 10.2913
# Early stopping, best iteration is:
# [1068]	training's rmse: 0.409424	valid_1's rmse: 10.2901
# fold2 RMSE score: 10.29006
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 7.26827	valid_1's rmse: 10.2168
# [200]	training's rmse: 5.01284	valid_1's rmse: 10.0022
# [300]	training's rmse: 3.59799	valid_1's rmse: 9.93242
# [400]	training's rmse: 2.64888	valid_1's rmse: 9.89908
# [500]	training's rmse: 1.97519	valid_1's rmse: 9.88253
# [600]	training's rmse: 1.49119	valid_1's rmse: 9.86704
# [700]	training's rmse: 1.13352	valid_1's rmse: 9.86286
# [800]	training's rmse: 0.865446	valid_1's rmse: 9.85804
# [900]	training's rmse: 0.664787	valid_1's rmse: 9.85568
# [1000]	training's rmse: 0.50893	valid_1's rmse: 9.85389
# [1100]	training's rmse: 0.390126	valid_1's rmse: 9.85295
# [1200]	training's rmse: 0.299284	valid_1's rmse: 9.85295
# [1300]	training's rmse: 0.231182	valid_1's rmse: 9.85109
# [1400]	training's rmse: 0.178434	valid_1's rmse: 9.84965
# [1500]	training's rmse: 0.137611	valid_1's rmse: 9.8492
# [1600]	training's rmse: 0.106587	valid_1's rmse: 9.84787
# [1700]	training's rmse: 0.0822025	valid_1's rmse: 9.8477
# [1800]	training's rmse: 0.0631473	valid_1's rmse: 9.84749
# [1900]	training's rmse: 0.0484852	valid_1's rmse: 9.84741
# [2000]	training's rmse: 0.0372888	valid_1's rmse: 9.84734
# Early stopping, best iteration is:
# [1937]	training's rmse: 0.0440113	valid_1's rmse: 9.8473
# fold3 RMSE score: 9.84730
# len(trn_idx) : 4348
# len(val_idx) : 1086
# Fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 7.31918	valid_1's rmse: 10.0646
# [200]	training's rmse: 5.0577	valid_1's rmse: 9.83847
# [300]	training's rmse: 3.62428	valid_1's rmse: 9.76177
# [400]	training's rmse: 2.66148	valid_1's rmse: 9.74208
# [500]	training's rmse: 1.97816	valid_1's rmse: 9.72797
# [600]	training's rmse: 1.48613	valid_1's rmse: 9.718
# [700]	training's rmse: 1.12185	valid_1's rmse: 9.7075
# [800]	training's rmse: 0.855411	valid_1's rmse: 9.70135
# [900]	training's rmse: 0.652481	valid_1's rmse: 9.69642
# [1000]	training's rmse: 0.499245	valid_1's rmse: 9.69246
# [1100]	training's rmse: 0.382201	valid_1's rmse: 9.6907
# [1200]	training's rmse: 0.292331	valid_1's rmse: 9.68901
# [1300]	training's rmse: 0.223468	valid_1's rmse: 9.68676
# [1400]	training's rmse: 0.170923	valid_1's rmse: 9.68625
# [1500]	training's rmse: 0.13157	valid_1's rmse: 9.68578
# [1600]	training's rmse: 0.101337	valid_1's rmse: 9.68603
# Early stopping, best iteration is:
# [1511]	training's rmse: 0.127818	valid_1's rmse: 9.68565
# fold4 RMSE score: 9.68565
# CV RMSE score: 9.73632
# =========================================================================================
# ### LGB for domain1_var1 ###
# ================================= 5fold lightgbm =================================
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 0
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 7.01472	valid_1's rmse: 9.74174
# [200]	training's rmse: 5.11401	valid_1's rmse: 9.73372
# Early stopping, best iteration is:
# [133]	training's rmse: 6.29707	valid_1's rmse: 9.71964
# fold0 RMSE score: 9.71964
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 7.028	valid_1's rmse: 9.57703
# [200]	training's rmse: 5.08876	valid_1's rmse: 9.57801
# Early stopping, best iteration is:
# [187]	training's rmse: 5.29644	valid_1's rmse: 9.56644
# fold1 RMSE score: 9.56644
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 7.03861	valid_1's rmse: 9.67864
# [200]	training's rmse: 5.13677	valid_1's rmse: 9.65982
# Early stopping, best iteration is:
# [172]	training's rmse: 5.59588	valid_1's rmse: 9.65619
# fold2 RMSE score: 9.65619
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 6.956	valid_1's rmse: 9.9651
# [200]	training's rmse: 5.05395	valid_1's rmse: 9.99106
# Early stopping, best iteration is:
# [102]	training's rmse: 6.90896	valid_1's rmse: 9.95993
# fold3 RMSE score: 9.95993
# len(trn_idx) : 4348
# len(val_idx) : 1086
# Fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 6.9659	valid_1's rmse: 10.1052
# [200]	training's rmse: 5.08391	valid_1's rmse: 10.0539
# Early stopping, best iteration is:
# [191]	training's rmse: 5.22349	valid_1's rmse: 10.0447
# fold4 RMSE score: 10.04470
# CV RMSE score: 9.79103
# =========================================================================================
# ### LGB for domain1_var2 ###
# ================================= 5fold lightgbm =================================
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 0
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 8.14718	valid_1's rmse: 11.5435
# Early stopping, best iteration is:
# [10]	training's rmse: 10.961	valid_1's rmse: 11.4504
# fold0 RMSE score: 11.45038
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 8.17046	valid_1's rmse: 11.4071
# Early stopping, best iteration is:
# [36]	training's rmse: 10.0365	valid_1's rmse: 11.3816
# fold1 RMSE score: 11.38163
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 8.15669	valid_1's rmse: 11.3517
# Early stopping, best iteration is:
# [15]	training's rmse: 10.8018	valid_1's rmse: 11.2489
# fold2 RMSE score: 11.24890
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 8.1052	valid_1's rmse: 11.5681
# Early stopping, best iteration is:
# [8]	training's rmse: 11.0416	valid_1's rmse: 11.4203
# fold3 RMSE score: 11.42029
# len(trn_idx) : 4348
# len(val_idx) : 1086
# Fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 8.19279	valid_1's rmse: 11.4232
# Early stopping, best iteration is:
# [6]	training's rmse: 11.1472	valid_1's rmse: 11.3471
# fold4 RMSE score: 11.34709
# CV RMSE score: 11.36988
# =========================================================================================
# ### LGB for domain2_var1 ###
# ================================= 5fold lightgbm =================================
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 0
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 7.80536	valid_1's rmse: 10.7065
# Early stopping, best iteration is:
# [66]	training's rmse: 8.74717	valid_1's rmse: 10.6802
# fold0 RMSE score: 10.68017
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 7.78643	valid_1's rmse: 10.9411
# Early stopping, best iteration is:
# [45]	training's rmse: 9.3917	valid_1's rmse: 10.9022
# fold1 RMSE score: 10.90218
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 7.77316	valid_1's rmse: 11.003
# Early stopping, best iteration is:
# [66]	training's rmse: 8.71785	valid_1's rmse: 10.9928
# fold2 RMSE score: 10.99277
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 7.74951	valid_1's rmse: 11.1394
# [200]	training's rmse: 5.66664	valid_1's rmse: 11.1772
# Early stopping, best iteration is:
# [111]	training's rmse: 7.4782	valid_1's rmse: 11.1275
# fold3 RMSE score: 11.12750
# len(trn_idx) : 4348
# len(val_idx) : 1086
# Fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 7.76508	valid_1's rmse: 11.1459
# [200]	training's rmse: 5.7116	valid_1's rmse: 11.1558
# Early stopping, best iteration is:
# [129]	training's rmse: 7.07609	valid_1's rmse: 11.1324
# fold4 RMSE score: 11.13235
# CV RMSE score: 10.96824
# =========================================================================================
# ### LGB for domain2_var2 ###
# ================================= 5fold lightgbm =================================
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 0
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 8.30991	valid_1's rmse: 11.9282
# Early stopping, best iteration is:
# [46]	training's rmse: 9.95067	valid_1's rmse: 11.8541
# fold0 RMSE score: 11.85407
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 8.37315	valid_1's rmse: 11.5629
# [200]	training's rmse: 6.16173	valid_1's rmse: 11.6088
# Early stopping, best iteration is:
# [128]	training's rmse: 7.67227	valid_1's rmse: 11.5539
# fold1 RMSE score: 11.55392
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 8.30849	valid_1's rmse: 11.8317
# Early stopping, best iteration is:
# [16]	training's rmse: 11.0827	valid_1's rmse: 11.8041
# fold2 RMSE score: 11.80414
# len(trn_idx) : 4347
# len(val_idx) : 1087
# Fold 3
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 8.32279	valid_1's rmse: 11.8526
# Early stopping, best iteration is:
# [52]	training's rmse: 9.7656	valid_1's rmse: 11.7991
# fold3 RMSE score: 11.79909
# len(trn_idx) : 4348
# len(val_idx) : 1086
# Fold 4
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 8.36851	valid_1's rmse: 11.6644
# Early stopping, best iteration is:
# [45]	training's rmse: 10.0445	valid_1's rmse: 11.624
# fold4 RMSE score: 11.62398
# CV RMSE score: 11.72764
# =========================================================================================

# %%
oof_df = pd.DataFrame()

for TARGET in TARGET_COLS:
    oof_df[TARGET] = oof_dict[TARGET]

# %%
# https://www.kaggle.com/akurmukov/trends-starter-rf-0-168-lb-metric

def lb_metric(y_true, y_pred):
    '''Computes lb metric, both y_true and y_pred should be DataFrames of shape n x 5'''
    y_true = y_true[['age', 'domain1_var1', 'domain1_var2','domain2_var1','domain2_var2']]
    y_pred = y_pred[['age', 'domain1_var1', 'domain1_var2','domain2_var1','domain2_var2']]
    weights = np.array([.3, .175, .175, .175, .175])
    return np.sum(weights * np.abs(y_pred.values - y_true.values).sum(axis=0) / y_true.values.sum(axis=0))

# %%
score = lb_metric(train, oof_df)
logger.info(f'Local Score: {score}')
# Out:
# Local Score: 0.16282096785496894

# %% [markdown]
# # Submission

# %%
sample_submission.head()
# Out:
#                    Id  Predicted
# 0           10003_age       50.0
# 1  10003_domain1_var1       50.0
# 2  10003_domain1_var2       50.0
# 3  10003_domain2_var1       50.0
# 4  10003_domain2_var2       50.0

# %%
pred_df = pd.DataFrame()

for TARGET in TARGET_COLS:
    tmp = pd.DataFrame()
    tmp[ID] = [f'{c}_{TARGET}' for c in test[ID].values]
    tmp['Predicted'] = prediction_dict[TARGET]
    pred_df = pd.concat([pred_df, tmp])

print(pred_df.shape)
print(sample_submission.shape)

pred_df.head()
# Out:
# (29385, 2)
# (29385, 2)
#           Id  Predicted
# 0  10003_age  49.079699
# 1  10006_age  56.684942
# 2  10010_age  40.736830
# 3  10011_age  46.662343
# 4  10012_age  57.134032

# %%
submission = sample_submission.drop(columns='Predicted').merge(pred_df, on=ID, how='left')
print(submission.shape)
submission.to_csv('submission.csv', index=False)
submission.head()
# Out:
# (29385, 2)
#                    Id  Predicted
# 0           10003_age  49.079699
# 1  10003_domain1_var1  49.900773
# 2  10003_domain1_var2  59.035311
# 3  10003_domain2_var1  48.143829
# 4  10003_domain2_var2  54.803257
