# %%
import numpy as np
from scipy.sparse import load_npz
from sklearn.decomposition import TruncatedSVD

import matplotlib.pyplot as plt
import seaborn as sns

# %%
ic2 = load_npz('/media/hiroki/working/kaggle_data/trends-neuroimaging/split_IC/train/IC/ic2_matrix.npz')

# %%
svd = TruncatedSVD(n_components=50, random_state=42)

# %%
ic2_50d = svd.fit_transform(ic2)

# %%
svd.explained_variance_ratio_
# Out:
# array([0.0032472 , 0.01645589, 0.00678679, 0.00376106, 0.00243237,
#        0.00201015, 0.00196063, 0.00180552, 0.00160205, 0.00156688,
#        0.00152555, 0.00146513, 0.00137358, 0.00136739, 0.00132111,
#        0.00129834, 0.00126097, 0.00123985, 0.00122661, 0.00121923,
#        0.00120249, 0.00116733, 0.00115807, 0.00114185, 0.0011276 ,
#        0.00111909, 0.00110976, 0.0011059 , 0.00109027, 0.00108896,
#        0.00108059, 0.00107058, 0.0010615 , 0.0010562 , 0.001052  ,
#        0.00104839, 0.0010406 , 0.00103109, 0.00102627, 0.00102294,
#        0.00101759, 0.0010131 , 0.00100809, 0.00100161, 0.00099845,
#        0.00099379, 0.00098588, 0.00098061, 0.00097418, 0.00097311])

# %%
sns.distplot(ic2_50d[:,0])

# %%
sns.distplot(ic2_50d[:,1])

# %%
sns.distplot(ic2_50d[:,2])

# %%
sns.distplot(ic2_50d[:,3])

# %%
#ic1
svd.explained_variance_ratio_
# Out:
# array([0.01568543, 0.01654133, 0.00547466, 0.00378081, 0.00255994,
#        0.00219413, 0.00179289, 0.00171771, 0.00160543, 0.00152389])

# %%
sns.distplot(ic1_2d[:,0])
plt.show()
sns.distplot(ic1_2d[:,1])
plt.show()
sns.distplot(ic1_2d[:,2])
plt.show()
sns.distplot(ic1_2d[:,3])
plt.show()
sns.distplot(ic1_2d[:,4])
plt.show()
sns.distplot(ic1_2d[:,5])
plt.show()

# %%
ic1_2d[:,0]
